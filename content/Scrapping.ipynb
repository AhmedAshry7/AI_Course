# %% [markdown]
# <h1> AI: </h1>
# 80% Data <br>
# . 90% Data Cleaning <br>
# . 10% Data Analysis
#
# 20% Modeling <br>
#
#
#
# AI Pipeline:
#
# 1. Verify(is there any other options)
# 2. Data Gathering ( Data collection , Data Accquring ) -->linear algebra
# 3. Data Preprocessing ( Organization )
# 4. Feature Engineering      (conclude insights) --> statistics , probability
# Solve Task--------------------------------------
# 5. Model Selection ( choose best algorithm )
# 6. Fit data into the model
# 7. Train
# 8. Test
# 81. Documentation
# 9. Integrate
# 10. Release
# 11. Monitor
# 12. Maintain

# %% [markdown]
# **Data Collection Methods:**
#
# 1. Available ( Direct Access )
# 2. Available ( free ) --> Download
# 3. Available ( not for free ) --> buy
# 4. Not available ( request )
# 5. Not available but exists ( Scrapping )
# 5. Not available ( create)
#
# How to create data: <br>
# 1- Surveys <br>
# 2- Data Entery
#
#
# Websites to get free data:
#
# 1. Google Dataset
# 2. Kaggle
# 3. Data.world
# 4. Hugging face
# 5. Academic Torrents

# %% [markdown]
# Web scrapping:
#
# 1- Beautifulsoup <br>
# 2- Requests ( api --> request )  <br>
# 3- Selunim ( automatic scrapping ) <br>
# 4- Cron jobs: ( Automatic method ) <br>
#
#
# Python:
# 1. Pip
# 2. Conda:

# %% [markdown]
# **Web Track** <br>
# frontend : Design  (html : hyper text markup langauage,css , js) <br>
# backend : Database, server and operations
#
#
# update : we can now write python directly into html
# <br>
# "<"py-script> python code "</"py-script>

# %%
# import requests                    #!pip install requests --> to get the page that i need to scrapping
from bs4 import BeautifulSoup      #beautiful soup version 4   --> to get information or parsing html
import csv

# !pip install lxml

# %%
x = "     Anas is amazing   "
x.strip()
# Out:
# 'Anas is amazing'

# %%
with open ("TextData/test.txt") as file: 
    y = file.readlines()
print(y)
print(len(y))

# y = [i.strip() for i in y ]   #is a list comprehension
# y
for i in y:
    print(i.strip())
# Out:
# ['This is a test file, and this is Saturday\n', 'this is another test \n', 'this is ItSharks']
# 3
# This is a test file, and this is Saturday
# this is another test
# this is ItSharks

# %%
# with open ('TextData/test.txt') as f: 
#     x = f.readline()[:-1]
# x

l1=[0,1,2,3,4,5,6]
print(l1[:-1])
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
with open ('simple.html') as html_file:
        soup = BeautifulSoup(html_file, 'lxml') # parser, #parsing  --> to convert byte code into simple code

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="">
# <head>
# <title> Web Scrapping session  </title>
# <meta charset="utf-8"/>
# <link href="css/normalize.css" rel="stylesheet"/>
# <link href="css/main.css" rel="stylesheet"/>
# <style>
# 		h1 {
# 			color: red;
# 			font-size: 50px;
# 		}
#
# 		#site_title2 {
# 			color: black;
# 			font-size: 20px;
# 		}
#
#
# 		.article {
# 			background-color: #60d6a5;
# 		}
#
#
#
#
# 	</style>
# </head>
# <body>
# <h1 id="site_title">    This is a web scrapping session before el eid    </h1>
# <h2> Another h2 Website </h2>
# <h3>Test Website with h3</h3>
# <hr/>
# <hr/>
# <section>
# <h2> This is a new section </h2>
# 		this is a new section for testing and debugging
#
#
# 	</section>
#
# Test Anything
#
#
# 	<hr/>
# <hr/>
# <article>
#
# 		this is new article
#
# 	</article>
# <hr/>
# <img class="css-9pa8cd" src="image.png"/>
# <div class="article">
# <h2>
# <a href="https://google.com"> Download now </a>
# </h2>
# ...

# %%
page=requests.get('https://www.yallakora.com/match-center/%D9%85%D8%B1%D9%83%D8%B2-%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA?date=6/18/2023#')
src=page.content

# %%
src
# Out:
# b'<!DOCTYPE html>\r\n<html lang="ar">\r\n<head>\r\n    <!-- strat: Chartbeat-->\r\n    <script type="text/javascript">\r\n        var _sf_startpt = (new Date()).getTime()\r\n    </script>\r\n    <!-- end: chartbeat-->\r\n\r\n    <meta charset="utf-8" />\r\n    <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">\r\n    <meta content="text/html; charset=UTF-8" http-equiv="content-type">\r\n    \r\n    <meta name="viewport" content="width=device-width, minimum-scale=1, initial-scale=1">\r\n    \r\n    \r\n\r\n\r\n    <!-- Download App Notification -->\r\n    \r\n\r\n\r\n\r\n\r\n    <meta name="apple-itunes-app" property="apple-itunes-app" content="app-id=377713182">\r\n    <meta name="google-play-app" property="google-play-app" content="app-id=com.inventivotech.yallakora">\r\n\r\n\r\n\r\n\r\n\r\n\r\n    <meta name="robots" content="max-snippet:-1, max-image-preview:large,max-video-preview:0">\r\n\r\n\r\n    <link href="https://www.yallakora.com//Images/Logo/favicon.ico?ver=1"
# ...

# %%
soupOne=BeautifulSoup(src,'lxml')
print(soupOne)
# Out:
# <!DOCTYPE html>
# <html lang="ar">
# <head>
# <!-- strat: Chartbeat-->
# <script type="text/javascript">
#         var _sf_startpt = (new Date()).getTime()
#     </script>
# <!-- end: chartbeat-->
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="width=device-width, minimum-scale=1, initial-scale=1" name="viewport"/>
# <!-- Download App Notification -->
# <meta content="app-id=377713182" name="apple-itunes-app" property="apple-itunes-app"/>
# <meta content="app-id=com.inventivotech.yallakora" name="google-play-app" property="google-play-app"/>
# <meta content="max-snippet:-1, max-image-preview:large,max-video-preview:0" name="robots"/>
# <link href="https://www.yallakora.com//Images/Logo/favicon.ico?ver=1" rel="icon" type="image/ico"/>
# <link href="https://www.yallakora.com//Images/Logo/favicon.ico?ver=1" rel="shortcut icon" type="image/x-icon"/>
# ...

# %%
print(soupOne.prettify())   #separate line for each tag and each string
# Out:
# <!DOCTYPE html>
# <html lang="ar">
#  <head>
#   <!-- strat: Chartbeat-->
#   <script type="text/javascript">
#    var _sf_startpt = (new Date()).getTime()
#   </script>
#   <!-- end: chartbeat-->
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="width=device-width, minimum-scale=1, initial-scale=1" name="viewport"/>
#   <!-- Download App Notification -->
#   <meta content="app-id=377713182" name="apple-itunes-app" property="apple-itunes-app"/>
#   <meta content="app-id=com.inventivotech.yallakora" name="google-play-app" property="google-play-app"/>
#   <meta content="max-snippet:-1, max-image-preview:large,max-video-preview:0" name="robots"/>
#   <link href="https://www.yallakora.com//Images/Logo/favicon.ico?ver=1" rel="icon" type="image/ico"/>
# ...

# %%
match = soup.title # print title tag 
print(match)
type(match)
# Out:
# <title> Web Scrapping session  </title>
# bs4.element.Tag

# %%
match = soup.title.text
print(match)
type(match)
# Out:
#  Web Scrapping session
# str

# %%
match = soup.div #  return the first div it can find
print(match)
print()
type(match)
# Out:
# <div class="article">
# <h2>
# <a href="https://google.com"> Download now </a>
# </h2>
# <p> This is a paragraph to explain how html works with web scrapping </p>
# </div>
# bs4.element.Tag

# %%
match = soup.find('div') # also, it will return the first div it could find
print(match)
# Out:
# <div class="article">
# <h2>
# <a href="https://google.com"> Download now </a>
# </h2>
# <p> This is a paragraph to explain how html works with web scrapping </p>
# </div>

# %%
match = soup.find('div', class_ = "footer")
print(match)
# Out:
# <div class="footer">
# <p>Footer Information</p>
# </div>

# %%
article = soup.find('div', {"id": "Ahmed", "class" : "article"})
print(article)
# Out:
# <div class="article" id="Ahmed">
# <h2>
# <a href="article_2.html">Article 3 Headline</a>
# </h2>
# <p>This is a summary of article 3</p>
# </div>

# %%
article = soup.find('div', class_ = "article")
print(article)
# Out:
# <div class="article">
# <h2>
# <a href="https://google.com"> Download now </a>
# </h2>
# <p> This is a paragraph to explain how html works with web scrapping </p>
# </div>

# %%
newheadline = article.h2.a.attrs["href"]
newheadline
# Out:
# 'https://google.com'

# %%
headlinelink = article.h2.a
print(headlinelink)
# Out:
# <a href="https://google.com"> Download now </a>

# %%
headline = article.h2.a.text
print(headline)
# Out:
#  Download now

# %%
summary = article.p.text
print(summary)
# Out:
#  This is a paragraph to explain how html works with web scrapping

# %%
articles = soup.find_all('div', class_ = "article")
print(type(articles))

print(len(articles))
print(articles)
print("       ")
for article in articles:
    
    headline = article.h2.a.text
    print(headline)
    
    summary = article.p.text
    print(summary)
    
    print('\n')
# Out:
# <class 'bs4.element.ResultSet'>
# 7
# [<div class="article">
# <h2>
# <a href="https://google.com"> Download now </a>
# </h2>
# <p> This is a paragraph to explain how html works with web scrapping </p>
# </div>, <div class="article">
# <h2>
# <a href="article_2.html">Article 2 Headline</a>
# </h2>
# <p>This is a summary of article 2</p>
# </div>, <div class="article" id="Ahmed">
# <h2>
# <a href="article_2.html">Article 3 Headline</a>
# </h2>
# <p>This is a summary of article 3</p>
# </div>, <div class="article">
# <h2>
# <a href="article_2.html">Article 4 Headline</a>
# </h2>
# <p>This is a summary of article 4</p>
# </div>, <div class="article">
# <h2>
# <a href="article_2.html">Article 5 Headline</a>
# </h2>
# <p>This is a summary of article 5</p>
# </div>, <div class="article">
# <h2>
# <a href="article_2.html">Article 6 Headline</a>
# </h2>
# <p>blaaadsfghj</p>
# </div>, <div class="article">
# <h2>
# <a href="article_2.html">Article 7 </a>
# </h2>
# ...

# %%
with open ('CoreyMS - Development, Design, DIY, and more.html') as html_file:
    soup = BeautifulSoup(html_file, 'lxml') # parser, #parsing

# %%
website = requests.get("http://coreyms.com").text # website link ( URL ) 
print(type(website)) # returns string ( website code) 
website
# retirieve website html code ( i.e. syntax)
# Out:
# <class 'str'>
# ...

# %%
soup = BeautifulSoup(website , 'lxml') # parsing ( understand txt string as html tags, id, class)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <!-- This site is optimized with the Yoast SEO plugin v15.4 - https://yoast.com/wordpress/plugins/seo/ -->
#   <title>
#    CoreyMS - Development, Design, DIY, and more
#   </title>
#   <meta content="Development, Design, DIY, and more" name="description"/>
#   <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>
#   <link href="https://coreyms.com/" rel="canonical"/>
#   <link href="https://coreyms.com/page/2" rel="next"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="website" property="og:type"/>
#   <meta content="CoreyMS - Development, Design, DIY, and more" property="og:title"/>
#   <meta content="Development, Design, DIY, and more" property="og:description"/>
#   <meta content="https://coreyms.com/" property="og:url"/>
# ...

# %%
title = soup.title.text
print(title)
# Out:
# CoreyMS - Development, Design, DIY, and more

# %%
article = soup.find('article') #tag which is called article , not the class article
# find first parameter is tag name ex: div, imd, p, article
print(article.prettify())
# Out:
# <article class="post-1670 post type-post status-publish format-standard has-post-thumbnail category-development category-python tag-gzip tag-shutil tag-zip tag-zipfile entry" itemscope="" itemtype="https://schema.org/CreativeWork">
#  <header class="entry-header">
#   <h2 class="entry-title" itemprop="headline">
#    <a class="entry-title-link" href="https://coreyms.com/development/python/python-tutorial-zip-files-creating-and-extracting-zip-archives" rel="bookmark">
#     Python Tutorial: Zip Files – Creating and Extracting Zip Archives
#    </a>
#   </h2>
#   <p class="entry-meta">
#    <time class="entry-time" datetime="2019-11-19T13:02:37-05:00" itemprop="datePublished">
#     November 19, 2019
#    </time>
#    by
#    <span class="entry-author" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
#     <a class="entry-author-link" href="https://coreyms.com/author/coreymschafer" itemprop="url" rel="author">
#      <span class="entry-author-name" itemprop="name">
# ...

# %%
headline = article.header.h2.a.text
print(headline)
# Out:
# Python Tutorial: Zip Files – Creating and Extracting Zip Archives

# %%
headline = article.h2.a.text
print(headline)
# Out:
# Python Tutorial: Zip Files – Creating and Extracting Zip Archives

# %%
headline = article.a.text
print(headline)
# Out:
# Python Tutorial: Zip Files – Creating and Extracting Zip Archives

# %%
l = article.a.attrs["href"]
print(l)
# Out:
# https://coreyms.com/development/python/python-tutorial-zip-files-creating-and-extracting-zip-archives

# %%
summary = article.find('div', class_ = "entry-content").p.text
print(summary)
print(type(summary))
# Out:
# In this video, we will be learning how to create and extract zip archives. We will start by using the zipfile module, and then we will see how to do this using the shutil module. We will learn how to do this with single files and directories, as well as learning how to use gzip as well. Let’s get started…
# <class 'str'>

# %% [markdown]
# **Task 1: python code : youtube link : donwload video** --> resolutions
# **Task 2: python code : scrap image**
# **Task 3: python code : scrap 5 articles and save them into csv file**    <br>
# **Task 4: github**
# **Task 5: python code : all your youtube subscribtions**

# %%
vid = article.find('iframe', class_= "youtube-player")
print(vid)
# Out:
# <iframe allowfullscreen="true" class="youtube-player" height="360" sandbox="allow-scripts allow-same-origin allow-popups allow-presentation" src="https://www.youtube.com/embed/z0gguhEmWiY?version=3&amp;rel=1&amp;showsearch=0&amp;showinfo=1&amp;iv_load_policy=1&amp;fs=1&amp;hl=en-US&amp;autohide=2&amp;wmode=transparent" style="border:0;" width="640"></iframe>

# %%
type(vid)
# Out:
# bs4.element.Tag

# %%
vid = article.find('iframe', class_= "youtube-player").attrs
print(vid)
print (type(vid))
# Out:
# {'class': ['youtube-player'], 'width': '640', 'height': '360', 'src': 'https://www.youtube.com/embed/z0gguhEmWiY?version=3&rel=1&showsearch=0&showinfo=1&iv_load_policy=1&fs=1&hl=en-US&autohide=2&wmode=transparent', 'allowfullscreen': 'true', 'style': 'border:0;', 'sandbox': ['allow-scripts', 'allow-same-origin', 'allow-popups', 'allow-presentation']}
# <class 'dict'>

# %%
vid = article.find('iframe', class_= "youtube-player").attrs['src']
print(vid)
print (type(vid))
# Out:
# https://www.youtube.com/embed/z0gguhEmWiY?version=3&rel=1&showsearch=0&showinfo=1&iv_load_policy=1&fs=1&hl=en-US&autohide=2&wmode=transparent
# <class 'str'>

# %%
vid = article.find('iframe', class_= "youtube-player")['src']
print(vid)
print (type(vid))
# Out:
# https://www.youtube.com/embed/z0gguhEmWiY?version=3&rel=1&showsearch=0&showinfo=1&iv_load_policy=1&fs=1&hl=en-US&autohide=2&wmode=transparent
# <class 'str'>

# %% [markdown]
# https://www.youtube.com/watch?v=3IZ36779aQc
# https://www.youtube.com/watch?v=uL9OczDLvYs

# %%
vid_id = vid.split('/')
vid_id
# Out:
# ['https:',
#  '',
#  'www.youtube.com',
#  'embed',
#  'z0gguhEmWiY?version=3&rel=1&showsearch=0&showinfo=1&iv_load_policy=1&fs=1&hl=en-US&autohide=2&wmode=transparent']

# %%
vid_id[-1]
# Out:
# 'z0gguhEmWiY?version=3&rel=1&showsearch=0&showinfo=1&iv_load_policy=1&fs=1&hl=en-US&autohide=2&wmode=transparent'

# %%
video = vid_id[4].split('?')
print(video)
# Out:
# ['z0gguhEmWiY', 'version=3&rel=1&showsearch=0&showinfo=1&iv_load_policy=1&fs=1&hl=en-US&autohide=2&wmode=transparent']

# %%
c = video[0]
print(c)
# Out:
# z0gguhEmWiY

# %%
ytLink = f'https://youtube.com/watch?v={c}' # print format 
print (ytLink)  #https://www.youtube.com/watch?v=3IZ36779aQc
# Out:
# https://youtube.com/watch?v=z0gguhEmWiY

# %%
try :
    vid = article.find('iframe', class_= "youtube-player")['src']
    vid_id = vid.split('/')
    video = vid_id[4].split('?')
    c =video[0]
    ytLink = f'https://youtube.com/watch?v={c}'
except Exception as e:
    print ("there was an error with the youtube link")
    print(e)
    
print(ytLink)
# Out:
# https://youtube.com/watch?v=z0gguhEmWiY

# %% [markdown]
# word : doc , rtf <br>
# xlsx : excel file extension ( can support multiple sheets ) <br>
# ( most common )csv : comma seperated values <br>
# example : <br>
# Ahmed,Mohamed,Ali,Mahmoud,Amr<br>
# Ahmed,Mohamed,Ali,Mahmoud,Amr<br>
# Ahmed,Mohamed,Ali,Mahmoud,Amr<br>
# Ahmed,Mohamed,Ali,Mahmoud,Amr

# %%
csvfile = open ('scrape4.csv', 'w', encoding='utf-8') # w = write into the file , general way of representing data 
writer = csv.writer(csvfile) # import csv 
writer.writerow(['headline', 'summary', 'link'])
# Out:
# 23

# %%
print(headline)
print()
print(summary)
print()
print(ytLink)
# Out:
# Python Tutorial: Zip Files – Creating and Extracting Zip Archives
#
# In this video, we will be learning how to create and extract zip archives. We will start by using the zipfile module, and then we will see how to do this using the shutil module. We will learn how to do this with single files and directories, as well as learning how to use gzip as well. Let’s get started…
#
# https://youtube.com/watch?v=z0gguhEmWiY

# %%
writer.writerow([headline, summary, ytLink])
# Out:
# 416

# %%
csvfile.close()

# %% [markdown]
# **Scrapping 10 articles into csv file**

# %%
csvfile = open ('scrape5.csv', 'w', encoding='utf-8') # w = write into the file , general way of representing data 
writer = csv.writer(csvfile)
writer.writerow(['headline', 'summary', 'link'])
articles = soup.find_all('article')
for i in articles: 
    headline = i.h2.a.text
    summary = i.find('div', class_ = "entry-content").p.text
    link = "None"
    try :
        vid = i.find('iframe', class_= "youtube-player")['src']
        vid_id = vid.split('/')
        video = vid_id[4].split('?')
        c =video[0]
        link = f'https://youtube.com/watch?v={c}'
    except Exception as e:
        link = "No link"
    
    writer.writerow([headline, summary , link])
csvfile.close()

# %%
import pandas as pd 
scrappedData = pd.read_csv("scrape5.csv",na_values="No link") # na_values="No link"
scrappedData
# Out:
#                                             headline  \
# 0  Python Tutorial: Zip Files – Creating and Extr...
# 1  Python Data Science Tutorial: Analyzing the 20...
# 2  Python Multiprocessing Tutorial: Run Code in P...
# 3  Python Threading Tutorial: Run Code Concurrent...
# 4                                Update (2019-09-03)
# 5  Python Quick Tip: The Difference Between “==” ...
# 6  Python Tutorial: Calling External Commands Usi...
# 7  Visual Studio Code (Windows) – Setting up a Py...
# 8  Visual Studio Code (Mac) – Setting up a Python...
# 9  Clarifying the Issues with Mutable Default Arg...
#
#                                              summary  \
# 0  In this video, we will be learning how to crea...
# 1  In this Python Programming video, we will be l...
# 2  In this Python Programming video, we will be l...
# 3  In this Python Programming video, we will be l...
# 4  Hey everyone. I wanted to give you an update o...
# 5  In this Python Programming Tutorial, we will b...
# ...

# %%
scrappedData.to_csv("scrapped6.csv")

# %%
from selenium import webdriver

# %%
driver = webdriver.Firefox(executable_path=r"geckodriver.exe")

# %%
driver.get("https://github.com")

# %% [markdown]
# 1- beautifulsoup ( bs4 )
# 2- requests
# 3- selenuim
#
#
# package ( versions )
# requests --> 3 beautiful soup
#
#
# force install

# %%
Data Collection: 
    
scrapping, buy, request, create, serveys
pip vs conda 
install package 
anaconda  prompt , jupyter 
coreate new environment 

web Scrapping: 
    
    API
    beautiful soup 4 
    requests 
    selenuim 
    csv ( already installed  )
    parser
    google trends, twitter 
    html files  
    html tags: 
        
        
Mathematics : 
    1- Statistics 
    2- Probability 
    3- Linear Algebra
    4- Calculus 

Data Science :
    Numpy, pandas, matplotlib
    Data Analysis
    Data Visualization 
    OpenCV ( Image processing , videos )
    Audio Analysis

# %%
print("Ahmed")
try: 
    print("Mohamed")
    print(creditcarddetails)
except:
    print("can't read your credit card, please try again")
# Out:
# Ahmed
# Mohamed
# can't read your credit card, please try again

# %%
source = requests.get('http://coreyms.com').text

soup = BeautifulSoup(source, 'lxml')

csv_file = open('cms_scrape.csv', 'w')

csv_writer = csv.writer(csv_file)
csv_writer.writerow(['headline', 'summary', 'video_link'])

for article in soup.find_all('article'):
    headline = article.h2.a.text
    print(headline)

    summary = article.find('div', class_='entry-content').p.text
    print(summary)

    try:
        vid_src = article.find('iframe', class_='youtube-player')['src']

        vid_id = vid_src.split('/')[4]
        vid_id = vid_id.split('?')[0]

        yt_link = f'https://youtube.com/watch?v={vid_id}'
    except Exception as e:
        yt_link = None

    print(yt_link)

    print()

    csv_writer.writerow([headline, summary, yt_link])

csv_file.close()
