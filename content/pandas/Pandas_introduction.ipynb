# %% [markdown]
# ### pandas : data preprocessing
# Also check : Pyspark, Dask

# %% [markdown]
# Data Scientist
#
# 1. Server ---> read data from server
# 2. Local --> access file through network, direct access
#
#
# . Sql Database
# . Oracle Database
# . Mongodb ( json objects )
# . Firebase
# . txt
# . log file
# . pdf
# . word
# . xls, xlsx
# . csv ( comma seperated values ==> Ahmed, Mohamed, Ali)
# . json ( javascript object notation )
# . Live data

# %%
import pandas as pd
df = pd.read_csv('anything/nyc.csv') # new york whether
#df = Data Frame 
df
# nan = not a number
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('anything/nyc.csv') # new york whether
#       3 #df = Data Frame
#       4 df
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
df.EST
# Out:
# 0      1/1/2016
# 1      1/2/2016
# 2      1/3/2016
# 3      1/4/2016
# 4      1/5/2016
# 5      1/6/2016
# 6      1/7/2016
# 7      1/8/2016
# 8      1/9/2016
# 9     1/10/2016
# 10    1/11/2016
# 11    1/12/2016
# 12    1/13/2016
# 13    1/14/2016
# 14    1/15/2016
# 15    1/16/2016
# 16    1/17/2016
# 17    1/18/2016
# 18    1/19/2016
# 19    1/20/2016
# 20    1/21/2016
# 21    1/22/2016
# 22    1/23/2016
# 23    1/24/2016
# 24    1/25/2016
# 25    1/26/2016
# 26    1/27/2016
# 27    1/28/2016
# 28    1/29/2016
# 29    1/30/2016
# 30    1/31/2016
# Name: EST, dtype: object

# %%
df["Sea Level PressureIn"]
# Out:
# 0     30.03
# 1     30.02
# 2     29.86
# 3     30.05
# 4     30.57
# 5     30.50
# 6     30.28
# 7     30.20
# 8     30.16
# 9     29.59
# 10    29.92
# 11    29.85
# 12    29.94
# 13    29.95
# 14    29.82
# 15    29.52
# 16    29.78
# 17    29.83
# 18    30.03
# 19    30.13
# 20    30.15
# 21    30.21
# 22    29.77
# 23    29.92
# 24    30.25
# 25    30.03
# 26    30.03
# 27    29.90
# 28    29.58
# 29    30.01
# 30    29.90
# Name: Sea Level PressureIn, dtype: float64

# %%
df["Sea Level PressureIn"].max()
# Out:
# 30.57

# %%
df["Sea Level PressureIn"] = df["Sea Level PressureIn"].astype("float32")
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52             30.030001
# 1    1/2/2016           36        18        46             30.020000
# 2    1/3/2016           40        21        47             29.860001
# 3    1/4/2016           25         9        44             30.049999
# 4    1/5/2016           20        -3        41             30.570000
# 5    1/6/2016           33         4        35             30.500000
# 6    1/7/2016           39        11        33             30.280001
# 7    1/8/2016           39        29        64             30.200001
# 8    1/9/2016           44        38        77             30.160000
# 9   1/10/2016           50        46        71             29.590000
# 10  1/11/2016           33         8        37             29.920000
# 11  1/12/2016           35        15        53             29.850000
# 12  1/13/2016           26         4        42             29.940001
# ...

# %%
df.Temperature
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
x =df.columns.to_list()
y=list(df.columns)
print(y)
print(x)
type(x)
# Out:
# ['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn', 'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover', 'Events', 'WindDirDegrees']
# list

# %%
for i in df.Temperature:
    if (i > 30):
        print(i)
# Out:
# 38
# 36
# 40
# 33
# 39
# 39
# 44
# 50
# 33
# 35
# 43
# 47
# 36
# 32
# 31
# 34
# 43
# 41
# 37
# 36
# 34
# 46

# %%
df.loc[0][0] #location
# Out:
# '1/1/2016'

# %%
df.columns[0]
# Out:
# 'EST'

# %%
counter = 0
for i in df.Temperature:
    if (i >= 30):
        counter+=1
counter
# Out:
# 23

# %%
counter = 0 
for i in df.Events: 
    if (i == "Rain"):
        counter+= 1
counter
# Out:
# 4

# %%
# df[ Condition ]
df [ df.Events == "Rain"   ]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77             30.160000
# 9   1/10/2016           50        46        71             29.590000
# 15  1/16/2016           47        37        70             29.520000
# 26  1/27/2016           41        22        45             30.030001
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 15                8           7.0            0.24           7   Rain
# 26               10           7.0               T           3   Rain
#
#     WindDirDegrees
# 8               76
# 9              109
# 15             340
# 26             311

# %%
#print(df['Temperature'])
df["EST"][df.Events == "Rain"]
#print(len(df["EST"][df.Events == "Rain"]))
#df[column] [condition]
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df["Temperature"][df.Events == "Rain"]
# Out:
# 8     44
# 9     50
# 15    47
# 26    41
# Name: Temperature, dtype: int64

# %%
print(df.DewPoint.dtype)
# Out:
# int64

# %%
print(df.WindSpeedMPH.dtype)
# Out:
# float64

# %%
df["Temperature"][df.Events == "Rain"]
# Out:
# 8     44
# 9     50
# 15    47
# 26    41
# Name: Temperature, dtype: int64

# %%
print(f"you have : {len(df.columns)} columns" )
# Out:
# you have : 11 columns

# %%
df["EST"][0]
# Out:
# '1/1/2016'

# %%
df['EST'][0:5]
# Out:
# 0    1/1/2016
# 1    1/2/2016
# 2    1/3/2016
# 3    1/4/2016
# 4    1/5/2016
# Name: EST, dtype: object

# %%
df.describe() #only works on numerical columns
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992910
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.139999
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
#  NAN --> not a number

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EST                   31 non-null     object
#  1   Temperature           31 non-null     int64
#  2   DewPoint              31 non-null     int64
#  3   Humidity              31 non-null     int64
#  4   Sea Level PressureIn  31 non-null     float32
#  5   VisibilityMiles       31 non-null     int64
#  6   WindSpeedMPH          28 non-null     float64
#  7   PrecipitationIn       31 non-null     object
#  8   CloudCover            31 non-null     int64
#  9   Events                9 non-null      object
#  10  WindDirDegrees        31 non-null     int64
# dtypes: float32(1), float64(1), int64(6), object(3)
# memory usage: 2.7+ KB

# %%
len(df['EST'][ df['Events']!= 'Rain'])
# Out:
# 27

# %%
len(df  [   df['Events']!= 'Rain'   ])
# Out:
# 27

# %%
df.fillna("?") # fill not a number values
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52             30.030001
# 1    1/2/2016           36        18        46             30.020000
# 2    1/3/2016           40        21        47             29.860001
# 3    1/4/2016           25         9        44             30.049999
# 4    1/5/2016           20        -3        41             30.570000
# 5    1/6/2016           33         4        35             30.500000
# 6    1/7/2016           39        11        33             30.280001
# 7    1/8/2016           39        29        64             30.200001
# 8    1/9/2016           44        38        77             30.160000
# 9   1/10/2016           50        46        71             29.590000
# 10  1/11/2016           33         8        37             29.920000
# 11  1/12/2016           35        15        53             29.850000
# 12  1/13/2016           26         4        42             29.940001
# ...

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
newdf = df.fillna(0)
newdf
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52             30.030001
# 1    1/2/2016           36        18        46             30.020000
# 2    1/3/2016           40        21        47             29.860001
# 3    1/4/2016           25         9        44             30.049999
# 4    1/5/2016           20        -3        41             30.570000
# 5    1/6/2016           33         4        35             30.500000
# 6    1/7/2016           39        11        33             30.280001
# 7    1/8/2016           39        29        64             30.200001
# 8    1/9/2016           44        38        77             30.160000
# 9   1/10/2016           50        46        71             29.590000
# 10  1/11/2016           33         8        37             29.920000
# 11  1/12/2016           35        15        53             29.850000
# 12  1/13/2016           26         4        42             29.940001
# ...

# %%
df.fillna(0, inplace=True) 
# df = df.fillna(0)

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52             30.030001
# 1    1/2/2016           36        18        46             30.020000
# 2    1/3/2016           40        21        47             29.860001
# 3    1/4/2016           25         9        44             30.049999
# 4    1/5/2016           20        -3        41             30.570000
# 5    1/6/2016           33         4        35             30.500000
# 6    1/7/2016           39        11        33             30.280001
# 7    1/8/2016           39        29        64             30.200001
# 8    1/9/2016           44        38        77             30.160000
# 9   1/10/2016           50        46        71             29.590000
# 10  1/11/2016           33         8        37             29.920000
# 11  1/12/2016           35        15        53             29.850000
# 12  1/13/2016           26         4        42             29.940001
# ...

# %%
import io
import requests
url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
s = requests.get(url).content
data = pd.read_csv(io.StringIO(s.decode('utf-8')))
data
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %%
# 1. pd.read_csv("direct url")
# 2. this way
