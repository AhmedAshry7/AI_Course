# %% [markdown]
# # Python Lists
#
# Lists are collection of different type of elements

# %%
a = 10
b = 20

# %%
a1 = 10
a2 = 20
a3 = 30

# %%
l = [10, 200, 30, 40]
print(l)
# Out:
# [10, 200, 30, 40]

# %%
l = ["A", 100, 5, 10.5,True]
#     0    1   2   3
print(l)
# Out:
# ['A', 100, 5, 10.5, True]

# %%
print(l[0])
# Out:
# A

# %%
print(l[3])
# Out:
# 10.5

# %%
print(l[2])
# Out:
# 5

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
print(type(l[0]))
# Out:
# <class 'str'>

# %%
print(type(l[3]))
# Out:
# <class 'float'>

# %%
a = 10
a = 20
print(a)
# Out:
# 20

# %%
s="abc"
s="d"+s[1:]
s
# Out:
# 'dbc'

# %%
l = [1,2,14,5]

l[0] = 10

print(l)
# Out:
# [10, 2, 14, 5]

# %%
n = 55

l = [1,2,3,n]

print(l)
# Out:
# [1, 2, 3, 55]

# %%
l = [1,2,3,44]

l[4] = 88

print(l)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-3004ff7f3a34> in <cell line: 3>()
#       1 l = [1,2,3,44]
#       2
# ----> 3 l[4] = 88
#       4
#       5 print(l)
#
# IndexError: list assignment index out of range

# %%
l = []

print(l)
# Out:
# []

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
#   -6  -5-4 - -23 -1
l = [70,50,3,50,20,10]
#    0  1  2  3 4  5

print(l[-1])
# Out:
# 10

# %%
print(l[-6])
# Out:
# 70

# %%
print(l[0])
# Out:
# 70

# %% [markdown]
# # List Slicing

# %%
n = [11,4,8,16,32,64,128,100,256]
#     0 1 2  3  4  5  6   7   8

print(n[0:4])
# Out:
# [11, 4, 8, 16]

# %%
print(n)
# Out:
# [11, 4, 8, 16, 32, 64, 128, 100, 256]

# %%
print(n[3:7])
# Out:
# [16, 32, 64, 128]

# %%
print(n[5:])
# Out:
# [64, 128, 100, 256]

# %%
print(n[:3])
# Out:
# [11, 4, 8]

# %%
print(n)
# Out:
# [11, 4, 8, 16, 32, 64, 128, 100, 256]

# %%
print(n[0:2])
# Out:
# [11, 4]

# %%
print(n[0:1])
# Out:
# [11]

# %%
print(n[0:4])
# Out:
# [11, 4, 8, 16]

# %%
print(n)
# Out:
# [11, 4, 8, 16, 32, 64, 128, 100, 256]

# %%
print(n[4:0])
# Out:
# []

# %%
print(n[-4:-1])
# Out:
# [64, 128, 100]

# %%
print(n[-1:-4])
# Out:
# []

# %%
print(n)
# Out:
# [11, 4, 8, 16, 32, 64, 128, 100, 256]

# %%
print(n[-7:])
# Out:
# [8, 16, 32, 64, 128, 100, 256]

# %%
print(n[-1:])
# Out:
# [256]

# %%
print(n[2:-4])
# Out:
# [8, 16, 32]

# %%
print(n)
# Out:
# [11, 4, 8, 16, 32, 64, 128, 100, 256]

# %%
print(n[:])
# Out:
# [11, 4, 8, 16, 32, 64, 128, 100, 256]

# %%
print(n[::2])  # steps
# Out:
# [11, 8, 32, 128, 256]

# %%
print(n[::4])
# Out:
# [11, 32, 256]

# %%
print(n[::1])
# Out:
# [11, 4, 8, 16, 32, 64, 128, 100, 256]

# %%
print(n[::-1])
# Out:
# [256, 100, 128, 64, 32, 16, 8, 4, 11]

# %%
print(n)
# Out:
# [11, 4, 8, 16, 32, 64, 128, 100, 256]

# %%
print(n[0:5:2])
# Out:
# [11, 8, 32]

# %%
print(n[8:1:])
# Out:
# []

# %%
print(n[8:1:-1])
# Out:
# [256, 100, 128, 64, 32, 16, 8]

# %%
print(n)
# Out:
# [11, 4, 8, 16, 32, 64, 128, 100, 256]

# %%
print(n[8:1:-2])
# Out:
# [256, 128, 32, 8]

# %%
print(n[4:1:-1])
# Out:
# [32, 16, 8]

# %%
print(n[1:4:-1])
# Out:
# []

# %%
print(n[1:7:0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-219e3b9d50fa> in <module>
# ----> 1 print(n[1:7:0])
#
# ValueError: slice step cannot be zero
